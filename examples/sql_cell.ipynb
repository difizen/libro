# %%
# %load_ext libro_sql

# %%
from libro_sql.database import db
db.config({
    'db_type': 'sqlite',
    'username': '',
    'password': '',
    'host': '',
    'port': 1111,
    'database': 'sql_demo.db'
})

# %%
# %%sql
# {"result_variable":"df_from_trans", "sql_script":"SELECT * FROM products"}
# Out:
#     id         product_name                                       description  \
# 0    1               Laptop       A high-performance laptop for professionals
# 1    2           Smartphone         A sleek smartphone with a powerful camera
# 2    3           Headphones              Noise-cancelling over-ear headphones
# 3    4           Smartwatch       A smartwatch with fitness tracking features
# 4    5               Tablet       A lightweight tablet with a 10-inch display
# 5    6     Wireless Charger             Fast wireless charger for smartphones
# 6    7         Gaming Mouse  Ergonomic gaming mouse with programmable buttons
# 7    8             Keyboard         Mechanical keyboard with RGB backlighting
# 8    9  External Hard Drive              1TB external hard drive with USB 3.0
# 9   10    Bluetooth Speaker        Portable Bluetooth speaker with rich sound
# 10  11              Monitor                            27-inch 4K UHD monitor
# ...

# %%
df_from_trans
# Out:
#     id         product_name                                       description  \
# 0    1               Laptop       A high-performance laptop for professionals
# 1    2           Smartphone         A sleek smartphone with a powerful camera
# 2    3           Headphones              Noise-cancelling over-ear headphones
# 3    4           Smartwatch       A smartwatch with fitness tracking features
# 4    5               Tablet       A lightweight tablet with a 10-inch display
# 5    6     Wireless Charger             Fast wireless charger for smartphones
# 6    7         Gaming Mouse  Ergonomic gaming mouse with programmable buttons
# 7    8             Keyboard         Mechanical keyboard with RGB backlighting
# 8    9  External Hard Drive              1TB external hard drive with USB 3.0
# 9   10    Bluetooth Speaker        Portable Bluetooth speaker with rich sound
# 10  11              Monitor                            27-inch 4K UHD monitor
# ...

# %%
# %%sql
# {"result_variable":"df_1", "sql_script":""}

# %%
# %%sql
# {"result_variable":"df_2", "sql_script":""}
