# %% [markdown]
# ## What is Libro?
# Libro is a customizable notebook solution designed to support generative AI capabilities. It delivers a commercial-grade user experience with seamless AI integration, making it easy to incorporate into your development environment and build cutting-edge AI and data science solutions.
#
# 🌟 GitHub: [https://github.com/difizen/libro](https://github.com/difizen/libro)
#
# 🌟 Website: [https://libro.difizen.net/](https://libro.difizen.net/)

# %%
import matplotlib.pyplot as plt
import numpy as np
x, y, sizes = np.random.rand(3, 50)
plt.scatter(x, y, s=sizes * 500, alpha=0.5, c=x, cmap='viridis')
plt.colorbar(label='Color Scale')
plt.title("Sample Scatter Plot")
plt.show()
